# %%
# Making the formula for deccorelation 
import numpy as np
import pandas as pd


def transform_to_ind(formula,
                     trainData,
                     trainLocs,
                     testData,
                     MaternParams=None,
                     smoothness=0.5,
                     M = 30,
                     ncores = 1):
    
    ## Figure out the nearest neighbors ##
    nnList = mkNNindx(trainLocs,M)



    
#     #################################################
#   ## Estimate a range and nugget if not provided ##
#   #################################################
#   if(is.null(MaternParams)){
#     mFit <- fit.NN.Matern(formula, data=trainData, locs=trainLocs, nu=smoothness,
#                           NearNeighs=nnList, num.cores=ncores)
#     range <- 1/mFit$decay
#     nugget <- mFit$nugget
#   } else {
#     range <- MaternParams[1]
#     nugget <- MaternParams[2]
#   }
  
#   ## Transform the dat
# Out:
# R[write to console]: Loading required package: coda
#
# R[write to console]: Loading required package: Formula
#
# R[write to console]: Loading required package: RANN

# %%
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Cell In[7], line 11
#       8 formula = f"{response_variable} ~ {' + '.join(all_variables)}"
#      10 # Create the design matrices
# ---> 11 y, X = dmatrices(formula, df, return_type='dataframe')
#      13 X
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/patsy/highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
# ...
